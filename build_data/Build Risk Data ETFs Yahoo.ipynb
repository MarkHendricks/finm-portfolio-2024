# %%
import pandas as pd
import numpy as np

import yfinance as yf
# Out:
# /Users/markhendricks/Projects/drw-markets-2024/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
TICKS = [
    'SPY',
    'VEA',
    'UPRO',
    'GLD',
    'USO',
    'FXE',
    'BTC-USD',
    'HYG',
    'IEF',
    'TIP',
    'SHV',
]

FLDS = ['quoteType','shortName','volume','totalAssets','longBusinessSummary']

# %%
info = pd.DataFrame(index=TICKS,columns=FLDS)
info.index.name = 'ticker'
for tick in info.index:
    temp = yf.Ticker(tick).get_info()

    for fld in FLDS:
        if fld in temp.keys():
            info.loc[tick,fld] = temp[fld]

# %%
prices = yf.download(TICKS, start="2017-01-01", end="2024-08-05")['Adj Close'][info.index]
prices.rename(columns={'BTC-USD':'BTC', 'CL=F':'CL1'},inplace=True)
prices.dropna(inplace=True)
rets = prices.pct_change().dropna()
# Out:
# [*********************100%%**********************]  11 of 11 completed

# %%
info
# Out:
#               quoteType                        shortName       volume  \
# ticker
# SPY                 ETF                     SPDR S&P 500    126096225
# VEA                 ETF  Vanguard FTSE Developed Markets     22548812
# UPRO                ETF       ProShares UltraPro S&P 500     13195956
# GLD                 ETF                  SPDR Gold Trust      8736540
# USO                 ETF           United States Oil Fund      3924918
# FXE                 ETF  Invesco CurrencyShares Euro Cur        44991
# BTC-USD  CRYPTOCURRENCY                      Bitcoin USD  65087082496
# HYG                 ETF  iShares iBoxx $ High Yield Corp    103766729
# IEF                 ETF  iShares 7-10 Year Treasury Bond     19070870
# TIP                 ETF            iShares TIPS Bond ETF      3172464
# SHV                 ETF  iShares Short Treasury Bond ETF      5539706
#
#           totalAssets                                longBusinessSummary
# ticker
# SPY      562499813376  The Trust seeks to achieve its investment obje...
# VEA      196265295872  The fund employs an indexing investment approa...
# UPRO       3573201920  The fund invests in financial instruments that...
# GLD       65976750080  The Trust holds gold bars and from time to tim...
# USO        1292349696  USO invests primarily in futures contracts for...
# FXE         174763792                                                NaN
# BTC-USD           NaN                                                NaN
# HYG       16805024768  The underlying index is a rules-based index co...
# IEF       29818413056  The underlying index measures the performance ...
# TIP       18333097984  The index tracks the performance of inflation-...
# SHV       19224520704  The fund will invest at least 80% of its asset...

# %%
rets
# Out:
# Ticker           SPY       VEA      UPRO       GLD       USO       FXE  \
# Date
# 2017-01-04  0.005949  0.012238  0.017834  0.003530  0.012238  0.009314
# 2017-01-05 -0.000794  0.008866 -0.003057  0.015515  0.010363  0.010896
# 2017-01-06  0.003578 -0.003995  0.011323 -0.007373 -0.001709 -0.006700
# 2017-01-09 -0.003301 -0.002406 -0.009447  0.008233 -0.031678  0.003617
# 2017-01-10  0.000000  0.001072 -0.001648  0.004260 -0.021220 -0.001071
# ...              ...       ...       ...       ...       ...       ...
# 2024-07-29  0.000588 -0.003979  0.000923 -0.001405 -0.012088 -0.002891
# 2024-07-30 -0.005066  0.002197 -0.015413  0.009985 -0.009709 -0.001300
# 2024-07-31  0.016255  0.014750  0.046695  0.018111  0.044050  0.001201
# 2024-08-01 -0.014161 -0.025535 -0.041161 -0.003443 -0.018652 -0.002995
# 2024-08-02 -0.018618 -0.017537 -0.056526 -0.001905 -0.038013  0.011654
#
# Ticker           BTC       HYG       IEF       TIP       SHV
# Date
# 2017-01-04  0.106233  0.005408  0.001145  0.002207 -0.000090
# 2017-01-05 -0.122410 -0.001488  0.006483  0.003435 -0.000091
# 2017-01-06 -0.109711 -0.000229 -0.004547 -0.004126  0.000272
# 2017-01-09  0.000695 -0.000229  0.003806  0.001587  0.000181
# 2017-01-10  0.005373  0.000115 -0.000474  0.000792 -0.000091
# ...              ...       ...       ...       ...       ...
# 2024-07-29 -0.016082 -0.000894  0.001684  0.001024  0.000181
# 2024-07-30 -0.009262  0.000511  0.002102  0.000744  0.000090
# 2024-07-31 -0.023893  0.003578  0.007340  0.005484  0.000090
# 2024-08-01  0.011425 -0.002189  0.004270  0.001324  0.000254
# 2024-08-02 -0.060321 -0.003335  0.015490  0.004808  0.000908
#
# [1907 rows x 11 columns]

# %%
with pd.ExcelWriter('../data/risk_etf_data.xlsx') as writer:  
    info.to_excel(writer, sheet_name= 'descriptions')
    rets.to_excel(writer, sheet_name='total returns')
    prices.to_excel(writer, sheet_name='prices')

# %%
info
# Out:
#               quoteType                        shortName       volume  \
# ticker
# SPY                 ETF                     SPDR S&P 500    126096225
# VEA                 ETF  Vanguard FTSE Developed Markets     22548812
# UPRO                ETF       ProShares UltraPro S&P 500     13195956
# GLD                 ETF                  SPDR Gold Trust      8736540
# USO                 ETF           United States Oil Fund      3924918
# FXE                 ETF  Invesco CurrencyShares Euro Cur        44991
# BTC-USD  CRYPTOCURRENCY                      Bitcoin USD  65087082496
# HYG                 ETF  iShares iBoxx $ High Yield Corp    103766729
# IEF                 ETF  iShares 7-10 Year Treasury Bond     19070870
# TIP                 ETF            iShares TIPS Bond ETF      3172464
# SHV                 ETF  iShares Short Treasury Bond ETF      5539706
#
#           totalAssets                                longBusinessSummary
# ticker
# SPY      562499813376  The Trust seeks to achieve its investment obje...
# VEA      196265295872  The fund employs an indexing investment approa...
# UPRO       3573201920  The fund invests in financial instruments that...
# GLD       65976750080  The Trust holds gold bars and from time to tim...
# USO        1292349696  USO invests primarily in futures contracts for...
# FXE         174763792                                                NaN
# BTC-USD           NaN                                                NaN
# HYG       16805024768  The underlying index is a rules-based index co...
# IEF       29818413056  The underlying index measures the performance ...
# TIP       18333097984  The index tracks the performance of inflation-...
# SHV       19224520704  The fund will invest at least 80% of its asset...
